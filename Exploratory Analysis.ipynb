# %% [markdown]
# # **Analysed the most important features of a diamonds dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('./data/diamonds_train.csv')

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.797706     61.752841     57.446133   3928.444469      5.729392
# std        0.475544      1.431725      2.233535   3992.416147      1.124453
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2397.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5331.000000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# max       58.900000      8.060000

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   price    40455 non-null  int64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# # **Exploratory Analysis of Numeric Data**

# %%
diamonds.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col1 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col3 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col4 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col5 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col6 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col3 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col4 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col5 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row2_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col0 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col4 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col5 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row3_col6 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col0 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col1 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col2 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col3 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col5 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row4_col6 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col0 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col3 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col4 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row5_col6 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col0 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col1 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col2 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col3 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col4 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col5 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_9e70efcc_d027_11ea_8cfe_632ab3458490row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9e70efcc_d027_11ea_8cfe_632ab3458490" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >carat</th>        <th class="col_heading level0 col1" >depth</th>        <th class="col_heading level0 col2" >table</th>        <th class="col_heading level0 col3" >price</th>        <th class="col_heading level0 col4" >x</th>        <th class="col_heading level0 col5" >y</th>        <th class="col_heading level0 col6" >z</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e70efcc_d027_11ea_8cfe_632ab3458490level0_row0" class="row_heading level0 row0" >carat</th>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col1" class="data row0 col1" >0.03</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col2" class="data row0 col2" >0.18</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col3" class="data row0 col3" >0.92</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col4" class="data row0 col4" >0.98</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col5" class="data row0 col5" >0.95</td>
#                         <td id="T_9e70efcc_d027_11ea_8cfe_632ab3458490row0_col6" class="data row0 col6" >0.

# %% [markdown]
# ### **Price by Size and Color**
#
# It is observed that the D color are more expensive with smaller diamond size while H and I need a larger diamonf to reach the same price
# D color have a exponential price increase with size while I and H have logarithmic

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 1, figsize = (20, 20))

sns.scatterplot(x = 'x', y = 'price', hue = 'color', data = diamonds, ax = ax[0])
sns.scatterplot(x = 'y', y = 'price', hue = 'color', data = diamonds, ax = ax[1])
ax[1].set_xlim([0, 15])
sns.scatterplot(x = 'z', y = 'price', hue = 'color', data = diamonds, ax = ax[2])

# %% [markdown]
# # **Exploratory Analysis of Categorical Data**
#
#
# ### **How Color Affect Price**
#
# The most expensives Diamonds are J color followed by I, H and G.
# Taking into account the cut type, the most expensive cut is Premium and the worst is Ideal

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (25, 10))


sns.barplot(x = 'color', y = 'price', data = diamonds, ax = ax[0])
sns.barplot(x = 'color', y = 'price', data = diamonds, hue = 'cut', ax = ax[1])

# %% [markdown]
# ### **How Clarity Affect Price**
#
# The most expensives Diamonds are SI2 clarity, followed by VS2, SI1 and I1.
# Taking into account color and clarity the most expensive diamond is a diamond of color D and clarity IF.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (30, 10))

sns.barplot(x = 'clarity', y = 'price', data = diamonds, ax = ax[0])
sns.barplot(x = 'clarity', y = 'price', data = diamonds, hue = 'color', ax = ax[1])

# %% [markdown]
# # **Conclusions**
